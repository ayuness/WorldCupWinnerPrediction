# %%
import pandas as pd
from pathlib import Path

# %%
df_results = pd.read_csv("./Data/WorldCupHistory/WorldCups_preview.csv")
print(df_results)
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
df_matches = pd.read_csv("./Data/WorldCupHistory/matches_1930_2022.csv")
print(df_matches)
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df_ranking = pd.read_csv("./Data/ranking_mundial_2026_v2.csv")
df_ranking= df_ranking.drop(columns=['team_name_es'])
print(df_ranking)
# Out:
#      country_code  year  ranking   date_used team_name         source   status
# 0             ALB  1993     92.0  1993-08-08   Albania   country_page  playoff
# 1             ALB  1994    100.0  1994-06-14   Albania   country_page  playoff
# 2             ALB  1995     91.0  1995-06-13   Albania   country_page  playoff
# 3             ALB  1996    116.0  1996-07-03   Albania   country_page  playoff
# 4             ALB  1997    116.0  1997-06-18   Albania   country_page  playoff
# ...           ...   ...      ...         ...       ...            ...      ...
# 2171          WAL  2022     28.0  2022-06-23     Wales   country_page  playoff
# 2172          WAL  2023     29.0  2023-06-29     Wales   country_page  playoff
# 2173          WAL  2024     29.0  2024-06-20     Wales   country_page  playoff
# 2174          WAL  2025     32.0  2025-07-10     Wales   country_page  playoff
# 2175          WAL  2026     35.0  2026-01-19     Wales  html_snapshot  playoff
#
# [2176 rows x 7 columns]

# %%
df_elimns_asia = pd.read_csv("./Data/Eliminatorias/eliminatorias_afc.csv")
print(df_elimns_asia)
# Out:
#    confederation      phase group  position country_code     status  pj  g  e  \
# 0            AFC  2da_ronda     A         1          QAT  confirmed   6  5  1
# 1            AFC  2da_ronda     B         1          JPN  confirmed   6  6  0
# 2            AFC  2da_ronda     C         1          KOR  confirmed   6  5  1
# 3            AFC  2da_ronda     E         1          IRN  confirmed   6  4  2
# 4            AFC  2da_ronda     E         2          UZB  confirmed   6  4  2
# 5            AFC  2da_ronda     F         1          IRQ    playoff   6  6  0
# 6            AFC  2da_ronda     G         1          JOR  confirmed   6  4  1
# 7            AFC  2da_ronda     G         2          KSA  confirmed   6  4  1
# 8            AFC  2da_ronda     I         1          AUS  confirmed   6  6  0
# 9            AFC   3ra_fase     A         1          IRN  confirmed  10  7  2
# 10           AFC   3ra_fase     A         2          UZB  confirmed  10  6  3
# ...

# %%
df_elimns_conmebol = pd.read_csv("./Data/Eliminatorias/eliminatorias_conmebol.csv")
print(df_elimns_conmebol)
# Out:
#   confederation       phase group  position country_code     status  pj   g  \
# 0      CONMEBOL  liga_unica     –         1          ARG  confirmed  18  12
# 1      CONMEBOL  liga_unica     –         2          ECU  confirmed  18   8
# 2      CONMEBOL  liga_unica     –         3          COL  confirmed  18   7
# 3      CONMEBOL  liga_unica     –         4          URU  confirmed  18   7
# 4      CONMEBOL  liga_unica     –         5          BRA  confirmed  18   8
# 5      CONMEBOL  liga_unica     –         6          PAR  confirmed  18   7
# 6      CONMEBOL  liga_unica     –         7          BOL    playoff  18   6
#
#    e   p  gf  gc  dg  pts  pts_per_game  win_pct  gf_per_game  gc_per_game
# 0  2   4  31  10  21   38         2.111    0.667        1.722        0.556
# 1  8   2  14   5   9   29         1.611    0.444        0.778        0.278
# 2  7   4  28  18  10   28         1.556    0.389        1.556        1.000
# ...

# %%
df_elimns_uefa = pd.read_csv("./Data/Eliminatorias/eliminatorias_uefa.csv")
print(df_elimns_uefa)
# Out:
#    country_code     status  pj  g  e  p  pts  gf  gc  dg  gf_per_game  \
# 0           NOR  confirmed   8  8  0  0   24  37   5  32        4.625
# 1           ENG  confirmed   8  8  0  0   24  22   0  22        2.750
# 2           CRO  confirmed   8  7  1  0   22  26   4  22        3.250
# 3           NED  confirmed   8  6  2  0   20  27   4  23        3.375
# 4           AUT  confirmed   8  6  1  1   19  22   4  18        2.750
# 5           BEL  confirmed   8  5  3  0   18  29   7  22        3.625
# 6           ESP  confirmed   6  5  1  0   16  21   2  19        3.500
# 7           FRA  confirmed   6  5  1  0   16  16   4  12        2.667
# 8           GER  confirmed   6  5  0  1   15  16   3  13        2.667
# 9           SUI  confirmed   6  4  2  0   14  14   2  12        2.333
# 10          SCO  confirmed   6  4  1  1   13  13   7   6        2.167
# 11          POR  confirmed   6  4  1  1   13  20   7  13        3.333
# ...

# %%
df_elimns_concacaf = pd.read_csv("./Data/Eliminatorias/eliminatorias_concacaf.csv")
print(df_elimns_concacaf)
# Out:
#   country_code     status        phase  position   pj    g    e    p   pts  \
# 0          USA  confirmed    anfitrion       NaN  NaN  NaN  NaN  NaN   NaN
# 1          MEX  confirmed    anfitrion       NaN  NaN  NaN  NaN  NaN   NaN
# 2          CAN  confirmed    anfitrion       NaN  NaN  NaN  NaN  NaN   NaN
# 3          CUW  confirmed  ronda_final       1.0  6.0  3.0  3.0  0.0  12.0
# 4          PAN  confirmed  ronda_final       2.0  6.0  3.0  3.0  0.0  12.0
# 5          JAM    playoff  ronda_final       3.0  6.0  3.0  2.0  1.0  11.0
# 6          HAI  confirmed  ronda_final       4.0  6.0  3.0  2.0  1.0  11.0
# 7          SUR    playoff  ronda_final       5.0  6.0  2.0  3.0  1.0   9.0
#
#      gf   gc    dg  gf_per_game  gc_per_game
# 0   NaN  NaN   NaN          NaN          NaN
# 1   NaN  NaN   NaN          NaN          NaN
# 2   NaN  NaN   NaN          NaN          NaN
# 3  13.0  3.0  10.0        2.167        0.500
# 4   9.0  4.0   5.0        1.500        0.667
# ...

# %%
df_elimns_caf = pd.read_csv("./Data/Eliminatorias/eliminatorias_caf.csv")
print(df_elimns_caf)
# Out:
#   country_code     status  pj  g  e  p  pts  gf  gc  dg  gf_per_game  \
# 0          TUN  confirmed  10  9  1  0   28  22   0  22         2.20
# 1          CIV  confirmed  10  8  2  0   26  25   0  25         2.50
# 2          EGY  confirmed  10  8  2  0   26  20   2  18         2.00
# 3          GHA  confirmed  10  8  1  1   25  23   6  17         2.30
# 4          ALG  confirmed  10  8  1  1   25  24   8  16         2.40
# 5          SEN  confirmed  10  7  3  0   24  22   3  19         2.20
# 6          MAR  confirmed   8  8  0  0   24  22   2  20         2.75
# 7          CPV  confirmed  10  7  2  1   23  16   8   8         1.60
# 8          RSA  confirmed  10  5  3  2   18  15   9   6         1.50
# 9          NGA    playoff  10  4  5  1   17  15   8   7         1.50
#
#    gc_per_game
# 0         0.00
# 1         0.00
# 2         0.20
# 3         0.60
# 4         0.80
# 5         0.30
# 6         0.25
# 7         0.80
# 8         0.90
# 9         0.80

# %%
df_elimns_ofc = pd.read_csv("./Data/Eliminatorias/eliminatorias_ofc.csv")
print(df_elimns_ofc)
# Out:
#   country_code     status  pj  g  e  p  pts  gf  gc  dg  gf_per_game  \
# 0          NZL  confirmed   5  5  0  0   15  29   1  28          5.8
# 1          NCL    playoff   5  3  1  1   10  10   7   3          2.0
#
#    gc_per_game
# 0          0.2
# 1          1.4

# %%
df_transfer = pd.read_csv("./Data/transfermarkt_selecciones.csv")
print(df_transfer.columns)
# Out:
# Index(['rank_tm', 'country_name_tm', 'country_code', 'confederation',
#        'members', 'avg_age', 'market_value_eur_m', 'avg_player_value_eur_m'],
#       dtype='object')
